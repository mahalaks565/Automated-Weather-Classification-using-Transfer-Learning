# %% [markdown]
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image1.png"
# style="width:8.5in;height:3.58056in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image2.png"
# style="width:8.5in;height:1.91944in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image3.png"
# style="width:8.5in;height:3.58056in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image4.png"
# style="width:8.5in;height:1.91944in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image5.png"
# style="width:8.5in;height:3.58056in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image6.png"
# style="width:8.5in;height:1.91944in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image7.png"
# style="width:8.5in;height:3.58056in" />
#
# <img
# src="attachment:vertopal_aaf797371a4b4417a86c82fa7d7d6b44/media/image8.png"
# style="width:8.5in;height:1.91944in" />
